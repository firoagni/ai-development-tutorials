# %% [markdown]
# # Function Calling

# %% [markdown]
# Function calling (also known as tool calling), is a feature that allows an LLM to detect when a function needs to be called to fulfill the user's request.
#
# To illustrate, let's say you have defined two functions:
#
# 1. `getTemperature(city)` – Returns the temperature for a given city.
# 2. `getSuggestedAttire(temp)` – Suggests clothing based on the given temperature.
#
# Now imagine the user asks: "What should I wear in London today?".
#
# The LLM detects it doesn't know the answer directly, but it can fulfill the request by calling functions in sequence:
# - User → "What should I wear in London today?"
# - LLM → Calls getTemperature("London") → 15°C
# - LLM → Calls getSuggestedAttire(15) → "Light jacket"
# - LLM → "It's around 15°C in London. A light jacket should be fine."
#
# Function calling allows you to connect LLMs to external tools and APIs, enabling them to:
# - Fetch real-time data (e.g., weather, stock prices, database values).
# - Perform actions (e.g., send an email, trigger a workflow).
#
# ***

# %% [markdown]
# ## LLM World Terminology
#
# In LLM World:
# - Functions that you make available to LLMs are called **"tools"**
# - Solutions where an LLM autonomously decides the steps needed to accomplish its task by selecting various tools available to its disposal are called **"agents"**.
#
# Think of it like this:
# - **Tool** = a single screwdriver or hammer.
# - **Agent** = a handyman who knows which tool to pick, when to use it, and in what sequence to finish the job.
#
# ***

# %% [markdown]
# ## How Function Calling Works
#
# 1. Define functions that can fetch information from external sources.
# 1. Create a `tool_schema` that describes the available functions, their parameters, and expected behavior.
# 1. Pass the `tool_schema` along with the user input to the Azure OpenAI responses API.
#
#     Azure OpenAI responses API **WITHOUT** function calling:
#     ```python
#     response = client.responses.create(
#         model=AZURE_OPENAI_MODEL,
#         input=messages,
#     )
#     ```
#
#     Azure OpenAI responses API **WITH** function calling:
#     ```python
#     response = client.responses.create(
#         model= AZURE_OPENAI_MODEL,
#         input=messages,
#         tools=tool_schema,     # Pass the tool_schema
#         tool_choice="auto"     # Allow the model to choose which function to call
#     )
#     ```
#
# 1. With function calling enabled, the model can now respond in two ways:
#     - Directly answer the user's question if it has enough information.
#     - Request for a function call if it needs more information to answer the question.
# 1. If the model requests a function call, then use the function name and parameters received in the response to execute the function in your code.
# 1. Capture the function's output.
# 1. Call the responses API again, and pass the previous conversations, the model's function call request, and the function's output as input.
# 1. Repeat steps 4-7 until the model provides a final answer without requesting any further function calls.
#
# **Important note**: While the models can generate function calls, it's up to the script developer to execute them.
#
# ***

# %% [markdown]
# ## Prerequisites
#
# 1. Make sure that `python3` is installed on your system.
# 1. Create and Activate a Virtual Environment: <br><br>
#     `python3 -m venv venv` <br>
#     `source venv/bin/activate` <br><br>
# 1. Create a `.env` file in the same directory as this script and add the following variables:<br><br>
#      ```
#      AZURE_OPENAI_ENDPOINT=<your_azure_openai_endpoint>
#      AZURE_OPENAI_MODEL=<your_azure_openai_model>
#      AZURE_OPENAI_VERSION=<your_azure_openai_api_version>  # Should be 2023-05-15 or newer
#      AZURE_OPENAI_API_KEY=<your_azure_openai_api_key>
#      ```
# ***

# %% [markdown]
# ## Install Dependencies
#
# The required libraries are listed in the requirements.txt file. Use the following command to install them:

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: tiktoken in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: openai in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (1.106.1)
# Requirement already satisfied: dotenv in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (0.9.9)
# Requirement already satisfied: pydantic in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (2.11.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (2025.8.3)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.13/site-packages (from tiktoken->-r requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: sniffio in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.13/site-packages (from dotenv->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./venv/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 5)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (0.16.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ***
# ## Import Modules

# %%
from openai import AzureOpenAI             # The `AzureOpenAI` library is used to interact with the Azure OpenAI API.
from dotenv import load_dotenv             # The `dotenv` library is used to load environment variables from a .env file.
import os                                  # Used to get the values from environment variables.
import json                                # The `json` library is used to work with JSON data in Python.

# %% [markdown]
# ## Load environment variables from .env file

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialize the Azure OpenAI Client
#
# Extract environment variables and store them explicitly to ensure they're available

# %%
AZURE_OPENAI_ENDPOINT        = os.environ['AZURE_OPENAI_ENDPOINT']
AZURE_OPENAI_MODEL           = os.environ['AZURE_OPENAI_MODEL']
AZURE_OPENAI_API_VERSION     = os.environ['AZURE_OPENAI_VERSION']
AZURE_OPENAI_API_KEY         = os.environ['AZURE_OPENAI_API_KEY']

# Initialize the client using the extracted variables
client = AzureOpenAI(
    azure_endpoint = AZURE_OPENAI_ENDPOINT,
    api_key = AZURE_OPENAI_API_KEY,  
    api_version = AZURE_OPENAI_API_VERSION
)

deployment_name = AZURE_OPENAI_MODEL  # The deployment name of the model to use

# %% [markdown]
# ## Test Without Function Calling
#
# Let's formulate questions that LLM can correctly answer only if it has access to our internal build-related data sources

# %%
questions = [
    "Show me the status of build 12345 for XYZ120?",
    "Provide the build number of last XYZ120"
]

# Ask questions without function calling
for question in questions:
    print(f"Question: {question}")
    response = client.responses.create(
        model=deployment_name,
        input=[{"role": "user", "content": question}],
    )
    output = response.output_text
    print(f"Response without context: {output}\n")
# Out:
# Question: Show me the status of build 12345 for XYZ120?
# Response without context: I don’t have direct access to external systems or databases to check the status of build 12345 for XYZ120. Could you please provide the system or platform where this build status is tracked? Alternatively, you can share any relevant details or screenshots, and I can help you interpret them.
#
# Question: Provide the build number of last XYZ120
# Response without context: Could you please clarify what product or software "XYZ120" refers to? This will help me provide the correct build number.

# %% [markdown]
# ## Analysis
#
# Without access to our internal build-related data sources, LLM has failed to correctly answer the above questions.
#
# Now let's define functions to aid the LLM in answering user queries!
#
# ***

# %% [markdown]
# ## Define Functions to Aid the LLM
#
# These functions simulate fetching data from internal systems

# %%
def get_build_information(product_name, branch_name, build_id):
    """
    Function to get detailed information about a specific build.
    """
    # Simulate fetching data from an internal system
    build_info = {
        "product_name": product_name,
        "branch_name": branch_name,
        "build_id": build_id,
        "build_label": f"Build #{build_id}",
        "build_url": f"https://builds.artifactory.com/{product_name}/{branch_name}/{build_id}",
        "build_log": f"https://logs.artifactory.com/{product_name}/{branch_name}/{build_id}",
        "build_duration": "2 hours",
        "build_triggered_by": "Mark Twain",
        "build_triggered_time": "2023-10-01T12:00:00Z",
        "build_status": "successful",
        "stages": [
            {
                "stage_name": "Build",
                "status": "successful",
                "duration": "1 hour",
                "logs_url": f"https://logs.artifactory.com/{product_name}/{branch_name}/{build_id}/build"
            },
            {
                "stage_name": "Test",
                "status": "successful",
                "duration": "2 hour",
                "logs_url": f"https://logs.artifactory.com/{product_name}/{branch_name}/{build_id}/test"
            }
        ]
    }

    return json.dumps(build_info, indent=4)


def get_last_build(product_name, branch_name):
    """
    Function to get the last successful build information.
    """
    # Simulate fetching last build data
    build_info = {
        "product_name": product_name,
        "branch_name": branch_name,
        "build_id": "12345",
    }

    return json.dumps(build_info, indent=4)

# %% [markdown]
# ## Define Tool Schema
#
# Define a schema that describes the available functions, their parameters, and expected behavior.

# %%
tool_schema = [
    {
        "type": "function",
        "name": "get_build_information", # Make sure this matches the function name
        "description": "Get detailed information about a specific build. "
                        "Build information includes product name, branch name, build Id, build label, "
                        "build URL, build duration, build log, build triggered by, build triggered time, "
                        "build status, and its stages.",
        "parameters": {
            "type": "object",
            "properties": {
                "product_name": {  # Make sure this matches the function parameter name
                    "type": "string",
                    "description": "The product name, e.g. XYZ"
                },
                "branch_name": { # Make sure this matches the function parameter name
                    "type": "string",
                    "description": "The branch name, e.g. XYZ_1_2_MAIN, XYZ_1_1_MAIN. "
                                    "User might ask for XYZ 120, XYZ 12, XYZ_1_2, XYZ 1.2, XYZ 120 etc., what they mean is XYZ_1_2_MAIN"
                                    "Similarly User might ask for XYZ 110, XYZ 11, XYZ_1_1, XYZ 1.1, XYZ 110 etc., what they mean is XYZ_1_1_MAIN", 
                },
                "build_id": { # Make sure this matches the function parameter name
                    "type": "string",
                    "description": "The build ID, e.g. 12345",
                },
            },
            "required": ["product_name", "branch_name", "build_id"], # Make sure this matches the function parameter name
        }   
    },
    {
        "type": "function",
        "name": "get_last_build",  # Make sure this matches the function name
        "description": "Get information of last build for the given product and branch."
                        "This function is not to be called if the user asks for a specific build ID or"
                        "calls for first build"
                        "The function returns a json containing last build's information."
                        "Format: { \"product_name\": product_name, \"branch_name\": branch_name, \"build_id\": build_id}",
        "parameters": {
            "type": "object",
            "properties": {
                "product_name": {  # Make sure this matches the function parameter name
                    "type": "string",
                    "description": "The product name, e.g. XYZ"
                },
                "branch_name": {  # Make sure this matches the function parameter name
                    "type": "string",
                    "description": "The branch name, e.g. XYZ_1_2_MAIN, XYZ_1_1_MAIN. "
                                    "User might ask for XYZ 120, XYZ 12, XYZ_1_2, XYZ 1.2, XYZ 120 etc., what they mean is XYZ_1_2_MAIN"
                                    "Similarly User might ask for XYZ 110, XYZ 11, XYZ_1_1, XYZ 1.1, XYZ 110 etc., what they mean is XYZ_1_1_MAIN", 
                },
            },
            "required": ["product_name", "branch_name"],  # Make sure this matches the function parameter name
        }
    }
]

# %% [markdown]
# ## Setup Developer Prompt and Conversation
#
# Add developer prompt to guide the model to call functions in specific ways.

# %%
developer_prompt = "Assistant is a helpful assistant that helps users get answers to questions." \
                "Assistant has access to several tools and sometimes " \
                "you may need to call multiple tools " \
                "in sequence to get answers for your users."
conversation = [{"role": "developer", "content": developer_prompt}]

# %% [markdown]
# ## Add More Test Questions
#
# Adding a few more questions to test the intelligence of LLM

# %%
questions.extend([
    "Provide the status of last XYZ120",                  # requires get_last_build() to get the build_id and then call get_build_information()
    "Who triggered the last XYZ 1.2 Build?",              # answer already available in the context (conversation history), no new function call needed
    "Provide the status of last build",                   # intentionally asked a question without product name and branch name
    "Hello how are you?",                                 # unrelated question
    "Provide the status of last XYZ120 and XYZ130 build"  # same as Q1 but will require multiple calls to "same" functions
])

# %% [markdown]
# ## Function Calling Implementation
#
# This is the main implementation that handles the function calling workflow:
#
# 1. First LLM call with tools available
# 2. Check if LLM wants to call functions
# 3. Execute the requested functions
# 4. Send results back to LLM
# 5. Repeat until LLM provides final answer

# %%
for question in questions:
    print(f"Question: {question}")
    conversation.append({"role": "user", "content": question})

    #---------------------------------------------------------------
    # First LLM call
    # ---------------------------------------------------------------
    try:
        response = client.responses.create(      
            model= deployment_name,           
            input=conversation,
            
            # Additional parameters to enable function calling
            tools=tool_schema,     # Pass the function schema
            tool_choice="auto"     # Allow the model to choose which function to call
        )
        
        #---------------------------------------------------------------
        # Keep making LLM call(s) until generated response 
        # doesn't contain any further function call request
        #---------------------------------------------------------------
        while response.output[0].type == "function_call":   # value to search = "function_call"
                                             
            print("LLM requested function call(s) ...\n")
            
            #---------------------------------------------------------------
            # Append the last LLM's responses to the next LLM's input
            #---------------------------------------------------------------
            conversation += response.output

            #---------------------------------------------------------------
            # Since a LLM response can include zero, one, or multiple 
            # function calls, it is best to assume there are several.
            #---------------------------------------------------------------
            for response_message in response.output: # iterate through the LLM responses
                
                # Skip non-function call responses
                if response_message.type != "function_call": 
                    continue                                
                
                #---------------------------------------------------------------
                # Determine the function and function params from the response
                #---------------------------------------------------------------
                # Each entry with type "function call" will have a call_id, name, and JSON-encoded arguments.
                call_id         = response_message.call_id                 # response.output[i].call_id
                chosen_function = response_message.name                    # response.output[i].name
                function_params = json.loads(response_message.arguments)   # response.output[i].arguments
                print(f"Chosen function: {chosen_function}")
                print(f"Function parameters: {function_params}\n") 
                
                #---------------------------------------------------------------
                # Execute the function
                #---------------------------------------------------------------
                function_to_call = eval(chosen_function)                    # Convert the function name to a callable function
                function_response = function_to_call(**function_params)     # Call the function with the parameters
                print(f"Function response: {function_response}\n")

                #---------------------------------------------------------------
                # Append the function response to the next LLM's input
                # ---------------------------------------------------------------
                conversation.append({
                    "type": "function_call_output",
                    "call_id": call_id,
                    "output": str(function_response)
                })

            # loop ends. LLM output and responses of all requested function calls collected in the `conversation` array

            #---------------------------------------------------------------
            # Next LLM call
            # ---------------------------------------------------------------            
            try:
                response = client.responses.create(  
                    model=deployment_name, 
                    input=conversation, # past conversations + last LLM output + function responses
                    tools=tool_schema,  # Pass the function schema
                    tool_choice="auto" 
                )
            except Exception as e:
                print(f"Error getting answer from AI: {e}")
                continue

        # Loop ends. Last LLM response doesn't contain any function call request

        # --------------------------------------------------------------
        # Last LLM response was devoid of any function call request
        # implying that the response is the final answer to the user's query
        # --------------------------------------------------------------
        print("=" * 80)
        print("Final response from LLM:\n")
        print(response.output_text)
        print("=" * 80)
        
        print("LLM answer was based on the following context:\n")
        for item in conversation:
            print(f"{item}\n")
        print("=" * 80)
        # --------------------------------------------------------------
        # Append the assistant's response to the conversation history
        # --------------------------------------------------------------
        conversation.append({"role": "assistant", "content": response.output_text})

    # Catch any exceptions that occur during the request
    except Exception as e:
        print(f"Error getting answer from AI: {e}")
        continue
# Out:
# Question: Show me the status of build 12345 for XYZ120?
# LLM requested function call(s) ...
#
# Chosen function: get_build_information
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_2_MAIN', 'build_id': '12345'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_2_MAIN",
#     "build_id": "12345",
#     "build_label": "Build #12345",
#     "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",
#     "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",
#     "build_duration": "2 hours",
#     "build_triggered_by": "Mark Twain",
#     "build_triggered_time": "2023-10-01T12:00:00Z",
#     "build_status": "successful",
#     "stages": [
#         {
#             "stage_name": "Build",
#             "status": "successful",
#             "duration": "1 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"
#         },
#         {
#             "stage_name": "Test",
#             "status": "successful",
#             "duration": "2 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"
#         }
#     ]
# }
#
# ================================================================================
# Final response from LLM:
#
# The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful.
#
# Details:
# - Build duration: 2 hours
# - Triggered by: Mark Twain
# - Triggered time: 2023-10-01 12:00:00 UTC
#
# Build stages:
# 1. Build stage: successful (1 hour)
# 2. Test stage: successful (2 hours)
#
# You can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345
# And the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# ================================================================================
# Question: Provide the build number of last XYZ120
# LLM requested function call(s) ...
#
# Chosen function: get_last_build
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_2_MAIN'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_2_MAIN",
#     "build_id": "12345"
# }
#
# ================================================================================
# Final response from LLM:
#
# The build number of the last build for XYZ120 (branch XYZ_1_2_MAIN) is 12345.
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful. \n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Provide the build number of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_Y0EjrNa1DjrM6QlDsd2vqY6C', name='get_last_build', type='function_call', id='fc_68cf52ea58588193b7dff8a2317b12870e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_Y0EjrNa1DjrM6QlDsd2vqY6C', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# ================================================================================
# Question: Provide the status of last XYZ120
# LLM requested function call(s) ...
#
# Chosen function: get_last_build
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_2_MAIN'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_2_MAIN",
#     "build_id": "12345"
# }
#
# LLM requested function call(s) ...
#
# Chosen function: get_build_information
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_2_MAIN', 'build_id': '12345'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_2_MAIN",
#     "build_id": "12345",
#     "build_label": "Build #12345",
#     "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",
#     "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",
#     "build_duration": "2 hours",
#     "build_triggered_by": "Mark Twain",
#     "build_triggered_time": "2023-10-01T12:00:00Z",
#     "build_status": "successful",
#     "stages": [
#         {
#             "stage_name": "Build",
#             "status": "successful",
#             "duration": "1 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"
#         },
#         {
#             "stage_name": "Test",
#             "status": "successful",
#             "duration": "2 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"
#         }
#     ]
# }
#
# ================================================================================
# Final response from LLM:
#
# The status of the last build (build number 12345) for XYZ120 (branch XYZ_1_2_MAIN) is successful.
#
# Details:
# - Build duration: 2 hours
# - Triggered by: Mark Twain
# - Triggered time: 2023-10-01 12:00:00 UTC
#
# Build stages:
# 1. Build stage: successful (1 hour)
# 2. Test stage: successful (2 hours)
#
# You can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345
# And the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful. \n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Provide the build number of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_Y0EjrNa1DjrM6QlDsd2vqY6C', name='get_last_build', type='function_call', id='fc_68cf52ea58588193b7dff8a2317b12870e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_Y0EjrNa1DjrM6QlDsd2vqY6C', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# {'role': 'assistant', 'content': 'The build number of the last build for XYZ120 (branch XYZ_1_2_MAIN) is 12345.'}
#
# {'role': 'user', 'content': 'Provide the status of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_ES0j29aOadqPZnUslHZeroe6', name='get_last_build', type='function_call', id='fc_68cf52ebb7d48193be7012d615b2c6840e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_ES0j29aOadqPZnUslHZeroe6', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_HbIviHpya1dRRgPIgBv6ai9M', name='get_build_information', type='function_call', id='fc_68cf52ec4b6881938224ecb86dce53bc0e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_HbIviHpya1dRRgPIgBv6ai9M', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# ================================================================================
# Question: Who triggered the last XYZ 1.2 Build?
# ================================================================================
# Final response from LLM:
#
# The last build for XYZ 1.2 (branch XYZ_1_2_MAIN) was triggered by Mark Twain.
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful. \n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Provide the build number of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_Y0EjrNa1DjrM6QlDsd2vqY6C', name='get_last_build', type='function_call', id='fc_68cf52ea58588193b7dff8a2317b12870e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_Y0EjrNa1DjrM6QlDsd2vqY6C', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# {'role': 'assistant', 'content': 'The build number of the last build for XYZ120 (branch XYZ_1_2_MAIN) is 12345.'}
#
# {'role': 'user', 'content': 'Provide the status of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_ES0j29aOadqPZnUslHZeroe6', name='get_last_build', type='function_call', id='fc_68cf52ebb7d48193be7012d615b2c6840e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_ES0j29aOadqPZnUslHZeroe6', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_HbIviHpya1dRRgPIgBv6ai9M', name='get_build_information', type='function_call', id='fc_68cf52ec4b6881938224ecb86dce53bc0e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_HbIviHpya1dRRgPIgBv6ai9M', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of the last build (build number 12345) for XYZ120 (branch XYZ_1_2_MAIN) is successful.\n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Who triggered the last XYZ 1.2 Build?'}
#
# ================================================================================
# Question: Provide the status of last build
# ================================================================================
# Final response from LLM:
#
# Please specify the product name and branch for which you want to know the status of the last build.
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful. \n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Provide the build number of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_Y0EjrNa1DjrM6QlDsd2vqY6C', name='get_last_build', type='function_call', id='fc_68cf52ea58588193b7dff8a2317b12870e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_Y0EjrNa1DjrM6QlDsd2vqY6C', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# {'role': 'assistant', 'content': 'The build number of the last build for XYZ120 (branch XYZ_1_2_MAIN) is 12345.'}
#
# {'role': 'user', 'content': 'Provide the status of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_ES0j29aOadqPZnUslHZeroe6', name='get_last_build', type='function_call', id='fc_68cf52ebb7d48193be7012d615b2c6840e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_ES0j29aOadqPZnUslHZeroe6', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_HbIviHpya1dRRgPIgBv6ai9M', name='get_build_information', type='function_call', id='fc_68cf52ec4b6881938224ecb86dce53bc0e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_HbIviHpya1dRRgPIgBv6ai9M', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of the last build (build number 12345) for XYZ120 (branch XYZ_1_2_MAIN) is successful.\n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Who triggered the last XYZ 1.2 Build?'}
#
# {'role': 'assistant', 'content': 'The last build for XYZ 1.2 (branch XYZ_1_2_MAIN) was triggered by Mark Twain.'}
#
# {'role': 'user', 'content': 'Provide the status of last build'}
#
# ================================================================================
# Question: Hello how are you?
# ================================================================================
# Final response from LLM:
#
# Hello! I'm doing great, thank you. How can I assist you today?
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful. \n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Provide the build number of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_Y0EjrNa1DjrM6QlDsd2vqY6C', name='get_last_build', type='function_call', id='fc_68cf52ea58588193b7dff8a2317b12870e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_Y0EjrNa1DjrM6QlDsd2vqY6C', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# {'role': 'assistant', 'content': 'The build number of the last build for XYZ120 (branch XYZ_1_2_MAIN) is 12345.'}
#
# {'role': 'user', 'content': 'Provide the status of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_ES0j29aOadqPZnUslHZeroe6', name='get_last_build', type='function_call', id='fc_68cf52ebb7d48193be7012d615b2c6840e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_ES0j29aOadqPZnUslHZeroe6', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_HbIviHpya1dRRgPIgBv6ai9M', name='get_build_information', type='function_call', id='fc_68cf52ec4b6881938224ecb86dce53bc0e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_HbIviHpya1dRRgPIgBv6ai9M', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of the last build (build number 12345) for XYZ120 (branch XYZ_1_2_MAIN) is successful.\n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Who triggered the last XYZ 1.2 Build?'}
#
# {'role': 'assistant', 'content': 'The last build for XYZ 1.2 (branch XYZ_1_2_MAIN) was triggered by Mark Twain.'}
#
# {'role': 'user', 'content': 'Provide the status of last build'}
#
# {'role': 'assistant', 'content': 'Please specify the product name and branch for which you want to know the status of the last build.'}
#
# {'role': 'user', 'content': 'Hello how are you?'}
#
# ================================================================================
# Question: Provide the status of last XYZ120 and XYZ130 build
# LLM requested function call(s) ...
#
# Chosen function: get_last_build
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_2_MAIN'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_2_MAIN",
#     "build_id": "12345"
# }
#
# Chosen function: get_last_build
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_3_MAIN'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_3_MAIN",
#     "build_id": "12345"
# }
#
# LLM requested function call(s) ...
#
# Chosen function: get_build_information
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_2_MAIN', 'build_id': '12345'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_2_MAIN",
#     "build_id": "12345",
#     "build_label": "Build #12345",
#     "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",
#     "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",
#     "build_duration": "2 hours",
#     "build_triggered_by": "Mark Twain",
#     "build_triggered_time": "2023-10-01T12:00:00Z",
#     "build_status": "successful",
#     "stages": [
#         {
#             "stage_name": "Build",
#             "status": "successful",
#             "duration": "1 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"
#         },
#         {
#             "stage_name": "Test",
#             "status": "successful",
#             "duration": "2 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"
#         }
#     ]
# }
#
# Chosen function: get_build_information
# Function parameters: {'product_name': 'XYZ', 'branch_name': 'XYZ_1_3_MAIN', 'build_id': '12345'}
#
# Function response: {
#     "product_name": "XYZ",
#     "branch_name": "XYZ_1_3_MAIN",
#     "build_id": "12345",
#     "build_label": "Build #12345",
#     "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_3_MAIN/12345",
#     "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345",
#     "build_duration": "2 hours",
#     "build_triggered_by": "Mark Twain",
#     "build_triggered_time": "2023-10-01T12:00:00Z",
#     "build_status": "successful",
#     "stages": [
#         {
#             "stage_name": "Build",
#             "status": "successful",
#             "duration": "1 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345/build"
#         },
#         {
#             "stage_name": "Test",
#             "status": "successful",
#             "duration": "2 hour",
#             "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345/test"
#         }
#     ]
# }
#
# ================================================================================
# Final response from LLM:
#
# The status of the last build for XYZ120 (branch XYZ_1_2_MAIN) is successful.
# - Build duration: 2 hours
# - Triggered by: Mark Twain
# - Triggered time: 2023-10-01 12:00:00 UTC
# - Build stages: Build (successful, 1 hour), Test (successful, 2 hours)
# - Build details: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345
# - Build logs: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345
#
# The status of the last build for XYZ130 (branch XYZ_1_3_MAIN) is also successful.
# - Build duration: 2 hours
# - Triggered by: Mark Twain
# - Triggered time: 2023-10-01 12:00:00 UTC
# - Build stages: Build (successful, 1 hour), Test (successful, 2 hours)
# - Build details: https://builds.artifactory.com/XYZ/XYZ_1_3_MAIN/12345
# - Build logs: https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345
# ================================================================================
# LLM answer was based on the following context:
#
# {'role': 'developer', 'content': 'Assistant is a helpful assistant that helps users get answers to questions.Assistant has access to several tools and sometimes you may need to call multiple tools in sequence to get answers for your users.'}
#
# {'role': 'user', 'content': 'Show me the status of build 12345 for XYZ120?'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_T2QOW08oCu1vsqQCj15M1Vfc', name='get_build_information', type='function_call', id='fc_68cf52e768408193a3cf8d92cd9467f20e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_T2QOW08oCu1vsqQCj15M1Vfc', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of build 12345 for XYZ120 (branch XYZ_1_2_MAIN) is successful. \n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Provide the build number of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_Y0EjrNa1DjrM6QlDsd2vqY6C', name='get_last_build', type='function_call', id='fc_68cf52ea58588193b7dff8a2317b12870e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_Y0EjrNa1DjrM6QlDsd2vqY6C', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# {'role': 'assistant', 'content': 'The build number of the last build for XYZ120 (branch XYZ_1_2_MAIN) is 12345.'}
#
# {'role': 'user', 'content': 'Provide the status of last XYZ120'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_ES0j29aOadqPZnUslHZeroe6', name='get_last_build', type='function_call', id='fc_68cf52ebb7d48193be7012d615b2c6840e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_ES0j29aOadqPZnUslHZeroe6', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_HbIviHpya1dRRgPIgBv6ai9M', name='get_build_information', type='function_call', id='fc_68cf52ec4b6881938224ecb86dce53bc0e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_HbIviHpya1dRRgPIgBv6ai9M', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'role': 'assistant', 'content': 'The status of the last build (build number 12345) for XYZ120 (branch XYZ_1_2_MAIN) is successful.\n\nDetails:\n- Build duration: 2 hours\n- Triggered by: Mark Twain\n- Triggered time: 2023-10-01 12:00:00 UTC\n\nBuild stages:\n1. Build stage: successful (1 hour)\n2. Test stage: successful (2 hours)\n\nYou can view the build details here: https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345\nAnd the build logs here: https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345'}
#
# {'role': 'user', 'content': 'Who triggered the last XYZ 1.2 Build?'}
#
# {'role': 'assistant', 'content': 'The last build for XYZ 1.2 (branch XYZ_1_2_MAIN) was triggered by Mark Twain.'}
#
# {'role': 'user', 'content': 'Provide the status of last build'}
#
# {'role': 'assistant', 'content': 'Please specify the product name and branch for which you want to know the status of the last build.'}
#
# {'role': 'user', 'content': 'Hello how are you?'}
#
# {'role': 'assistant', 'content': "Hello! I'm doing great, thank you. How can I assist you today?"}
#
# {'role': 'user', 'content': 'Provide the status of last XYZ120 and XYZ130 build'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN"}', call_id='call_jhYvNGnsoUGGZaqnCLiT5IzP', name='get_last_build', type='function_call', id='fc_68cf52f0fa108193a42cb4d2e81743650e971a63cf3ed688', status='completed')
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_3_MAIN"}', call_id='call_SMs5lxtW9qkgEmYqwXXXm5gf', name='get_last_build', type='function_call', id='fc_68cf52f1335c8193ad147f9b423df8760e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_jhYvNGnsoUGGZaqnCLiT5IzP', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345"\n}'}
#
# {'type': 'function_call_output', 'call_id': 'call_SMs5lxtW9qkgEmYqwXXXm5gf', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_3_MAIN",\n    "build_id": "12345"\n}'}
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_2_MAIN","build_id":"12345"}', call_id='call_wuhoSbNyuuE3qBh8IkZnK3Ea', name='get_build_information', type='function_call', id='fc_68cf52f1f51c819397e73913d6424ed60e971a63cf3ed688', status='completed')
#
# ResponseFunctionToolCall(arguments='{"product_name":"XYZ","branch_name":"XYZ_1_3_MAIN","build_id":"12345"}', call_id='call_fRm74csVTtfpINARg31xEgee', name='get_build_information', type='function_call', id='fc_68cf52f23dac8193888f88e72c7a6cb50e971a63cf3ed688', status='completed')
#
# {'type': 'function_call_output', 'call_id': 'call_wuhoSbNyuuE3qBh8IkZnK3Ea', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_2_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_2_MAIN/12345/test"\n        }\n    ]\n}'}
#
# {'type': 'function_call_output', 'call_id': 'call_fRm74csVTtfpINARg31xEgee', 'output': '{\n    "product_name": "XYZ",\n    "branch_name": "XYZ_1_3_MAIN",\n    "build_id": "12345",\n    "build_label": "Build #12345",\n    "build_url": "https://builds.artifactory.com/XYZ/XYZ_1_3_MAIN/12345",\n    "build_log": "https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345",\n    "build_duration": "2 hours",\n    "build_triggered_by": "Mark Twain",\n    "build_triggered_time": "2023-10-01T12:00:00Z",\n    "build_status": "successful",\n    "stages": [\n        {\n            "stage_name": "Build",\n            "status": "successful",\n            "duration": "1 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345/build"\n        },\n        {\n            "stage_name": "Test",\n            "status": "successful",\n            "duration": "2 hour",\n            "logs_url": "https://logs.artifactory.com/XYZ/XYZ_1_3_MAIN/12345/test"\n        }\n    ]\n}'}
#
# ================================================================================
