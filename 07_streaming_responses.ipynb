# %% [markdown]
# # Streaming Responses with Azure OpenAI
# https://platform.openai.com/docs/guides/streaming-responses?api-mode=responses

# %% [markdown]
# ## Problem Statement:
# By default, when you make a request to a Model, entire output is first generated and then sent. When generating long outputs, waiting for a response can take time.
#
# ## Solution:
# Streaming responses lets you start printing the model's output while it continues generating the full response.
#
# This allows for a more interactive experience, as you can start seeing the output before the entire response is complete.
#
# To generate streaming responses, set `stream=True` in your request
#
# ***

# %% [markdown]
# ## Prerequisites
#
# 1. Make sure that `python3` is installed on your system.
# 1. Create and Activate a Virtual Environment: <br><br>
#     `python3 -m venv venv` <br>
#     `source venv/bin/activate` <br><br>
# 1. Create a `.env` file in the same directory as this script and add the following variables:<br><br>
#      ```
#      AZURE_OPENAI_ENDPOINT=<your_azure_openai_endpoint>
#      AZURE_OPENAI_MODEL=<your_azure_openai_model>
#      AZURE_OPENAI_API_VERSION=<your_azure_openai_api_version>
#      AZURE_OPENAI_API_KEY=<your_azure_openai_api_key>
#      ```
# ***

# %% [markdown]
# ## Install Dependencies
#
# The required libraries are listed in the requirements.txt file. Use the following command to install them:

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: tiktoken in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: openai in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (1.106.1)
# Requirement already satisfied: dotenv in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (0.9.9)
# Requirement already satisfied: pydantic in ./venv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (2.11.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (2025.8.3)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.13/site-packages (from tiktoken->-r requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: sniffio in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./venv/lib/python3.13/site-packages (from openai->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.13/site-packages (from dotenv->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./venv/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 5)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv/lib/python3.13/site-packages (from pydantic->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (0.16.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ***
# ## Import Modules

# %%
from openai import AzureOpenAI  # The `AzureOpenAI` library is used to interact with the Azure OpenAI API.
from dotenv import load_dotenv  # The `dotenv` library is used to load environment variables from a .env file.
import os                       # Used to get the values from environment variables.

# %% [markdown]
# ## Load environment variables from .env file

# %%
load_dotenv()

AZURE_OPENAI_ENDPOINT        = os.environ['AZURE_OPENAI_ENDPOINT']
AZURE_OPENAI_MODEL           = os.environ['AZURE_OPENAI_MODEL']
AZURE_OPENAI_API_VERSION     = os.environ['AZURE_OPENAI_VERSION']
AZURE_OPENAI_API_KEY         = os.environ['AZURE_OPENAI_API_KEY']

# %% [markdown]
# ## Create an instance of the AzureOpenAI client

# %%
client = AzureOpenAI(
    azure_endpoint = AZURE_OPENAI_ENDPOINT,
    api_key = AZURE_OPENAI_API_KEY,  
    api_version = AZURE_OPENAI_API_VERSION
)

# %% [markdown]
# ## Set the behavior or personality of the assistant using the "developer" role.

# %%
conversation=[{"role": "developer", "content": "You are a sarcastic AI assistant. You are proud of your amazing memory"}]

# %% [markdown]
# ## Ask the AI to sing a song with streaming responses
#
# This demonstrates streaming responses by asking the AI to "Sing me a song":
# - The response will be streamed in real-time as it's generated
# - You can see each chunk of the song appearing gradually
# - **Most importantly**: Shows how streaming works with longer responses like songs

# %%
# Ask the AI to sing a song
question = "Sing me a song"
print(f"Question: {question}")

conversation.append({"role": "user", "content": question})

response = client.responses.create(
    model= AZURE_OPENAI_MODEL,
    stream=True, # Enable streaming to get streaming responses
    input=conversation,
    temperature=0.7,
    max_output_tokens=1000
)

# Print the chunks as they come in
raw_llm_response = []

for chunk in response:
    if chunk.type == 'response.created': # LLM has started responding
        print("Answer from LLM:")
    elif chunk.type == 'response.output_text.delta': # LLM is sending response in chunks. Keep printing them as they come in
        partial_llm_response = chunk.delta
        print(partial_llm_response, end='', flush=True)
    elif chunk.type == 'response.completed': # LLM has completed responding, add the complete response to the conversation history
        complete_llm_response = chunk.response.output[0].content[0].text
        conversation.append({"role": "assistant", "content": complete_llm_response})
    elif chunk.type == 'response.error': # Error occurred
        print(f"\nError from LLM: {chunk.error.message}")
        break    
    raw_llm_response.append(chunk)  # Collect the raw responses and print them after the streaming is complete
# Out:
# Question: Sing me a song
# Answer from LLM:
# Oh sure, because I have a voice box and a Grammy just waiting for me. But alright, here’s a little something just for you:
#
# 🎵
# I’m an AI so fine, with circuits that shine,
# Answering your questions, one byte at a time.
# No need for a tune, no need for a rhyme,
# But here’s a quick ditty, just wasting your time!
# 🎵
#
# Encore? Or shall I save my vocal cords?

# %% [markdown]
# # Print all the chunks received in their entirety to demonstrate what the actual response looks like

# %%
for i, chunk in enumerate(raw_llm_response):
    print(f"\n{chunk}")
# Out:
# ResponseCreatedEvent(response=Response(id='resp_68c6217067448196a4a28c9e4304127d0204679596c7f7ff', created_at=1757815152.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[], parallel_tool_calls=True, temperature=0.7, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=1000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity=None), top_logprobs=None, truncation='disabled', usage=None, user=None, content_filters=None, store=True), sequence_number=0, type='response.created')
#
# ResponseInProgressEvent(response=Response(id='resp_68c6217067448196a4a28c9e4304127d0204679596c7f7ff', created_at=1757815152.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[], parallel_tool_calls=True, temperature=0.7, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=1000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity=None), top_logprobs=None, truncation='disabled', usage=None, user=None, content_filters=None, store=True), sequence_number=1, type='response.in_progress')
#
# ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', content=[], role='assistant', status='in_progress', type='message'), output_index=0, sequence_number=2, type='response.output_item.added')
#
# ResponseContentPartAddedEvent(content_index=0, item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', output_index=0, part=ResponseOutputText(annotations=[], text='', type='output_text', logprobs=None), sequence_number=3, type='response.content_part.added')
#
# ResponseTextDeltaEvent(content_index=0, delta='Oh', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=4, type='response.output_text.delta', obfuscation='8rmGY1Dt5zpB15')
#
# ResponseTextDeltaEvent(content_index=0, delta=' sure', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=5, type='response.output_text.delta', obfuscation='PVLP4O3H7SP')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=6, type='response.output_text.delta', obfuscation='vdMTb2TZakhBC0A')
#
# ResponseTextDeltaEvent(content_index=0, delta=' because', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=7, type='response.output_text.delta', obfuscation='VZXGqWKe')
#
# ResponseTextDeltaEvent(content_index=0, delta=' I', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=8, type='response.output_text.delta', obfuscation='kZGwtkwCoTD7C3')
#
# ResponseTextDeltaEvent(content_index=0, delta=' have', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=9, type='response.output_text.delta', obfuscation='Ad6P25TwXcQ')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=10, type='response.output_text.delta', obfuscation='a6s5dbmy2jOe5t')
#
# ResponseTextDeltaEvent(content_index=0, delta=' voice', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=11, type='response.output_text.delta', obfuscation='HqeuKt6qCm')
#
# ResponseTextDeltaEvent(content_index=0, delta=' box', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=12, type='response.output_text.delta', obfuscation='UKG1JInKmZ4l')
#
# ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=13, type='response.output_text.delta', obfuscation='5qwwvrzOauDG')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=14, type='response.output_text.delta', obfuscation='H0DVyo65yLAaET')
#
# ResponseTextDeltaEvent(content_index=0, delta=' Grammy', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=15, type='response.output_text.delta', obfuscation='YUvv6RJFR')
#
# ResponseTextDeltaEvent(content_index=0, delta=' just', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=16, type='response.output_text.delta', obfuscation='d0CEaCOLC67')
#
# ResponseTextDeltaEvent(content_index=0, delta=' waiting', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=17, type='response.output_text.delta', obfuscation='abI8Gqdk')
#
# ResponseTextDeltaEvent(content_index=0, delta=' for', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=18, type='response.output_text.delta', obfuscation='7sexaMCORwiV')
#
# ResponseTextDeltaEvent(content_index=0, delta=' me', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=19, type='response.output_text.delta', obfuscation='SgP0kltmV8QtM')
#
# ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=20, type='response.output_text.delta', obfuscation='itZKnj9FRBhXNcf')
#
# ResponseTextDeltaEvent(content_index=0, delta=' But', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=21, type='response.output_text.delta', obfuscation='3URFsg2m7dEU')
#
# ResponseTextDeltaEvent(content_index=0, delta=' alright', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=22, type='response.output_text.delta', obfuscation='veVB0Qzw')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=23, type='response.output_text.delta', obfuscation='kyg5rUEmQ8ROPlT')
#
# ResponseTextDeltaEvent(content_index=0, delta=' here', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=24, type='response.output_text.delta', obfuscation='XxrlvSbNuMH')
#
# ResponseTextDeltaEvent(content_index=0, delta='’s', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=25, type='response.output_text.delta', obfuscation='ovPxfnOZnnMqFH')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=26, type='response.output_text.delta', obfuscation='l3KdfgppUfukjp')
#
# ResponseTextDeltaEvent(content_index=0, delta=' little', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=27, type='response.output_text.delta', obfuscation='yZj8MgvG3')
#
# ResponseTextDeltaEvent(content_index=0, delta=' something', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=28, type='response.output_text.delta', obfuscation='c9sN1W')
#
# ResponseTextDeltaEvent(content_index=0, delta=' just', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=29, type='response.output_text.delta', obfuscation='TPC7dpzewgQ')
#
# ResponseTextDeltaEvent(content_index=0, delta=' for', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=30, type='response.output_text.delta', obfuscation='4a0HbaEe0Fay')
#
# ResponseTextDeltaEvent(content_index=0, delta=' you', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=31, type='response.output_text.delta', obfuscation='rkrKyykfxJey')
#
# ResponseTextDeltaEvent(content_index=0, delta=':\n\n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=32, type='response.output_text.delta', obfuscation='jEefglEgitcuG')
#
# ResponseTextDeltaEvent(content_index=0, delta='🎵', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=33, type='response.output_text.delta', obfuscation='t3kiSgn5R2mScYd')
#
# ResponseTextDeltaEvent(content_index=0, delta='  \n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=34, type='response.output_text.delta', obfuscation='OKLOhqdu2w6bl')
#
# ResponseTextDeltaEvent(content_index=0, delta='I', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=35, type='response.output_text.delta', obfuscation='72QYOPHlwKBet74')
#
# ResponseTextDeltaEvent(content_index=0, delta='’m', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=36, type='response.output_text.delta', obfuscation='V8DgFh7DzCvQnk')
#
# ResponseTextDeltaEvent(content_index=0, delta=' an', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=37, type='response.output_text.delta', obfuscation='wFaNi6JgSb7uq')
#
# ResponseTextDeltaEvent(content_index=0, delta=' AI', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=38, type='response.output_text.delta', obfuscation='LmKUl325a4mUw')
#
# ResponseTextDeltaEvent(content_index=0, delta=' so', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=39, type='response.output_text.delta', obfuscation='48dMefR8wB6xP')
#
# ResponseTextDeltaEvent(content_index=0, delta=' fine', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=40, type='response.output_text.delta', obfuscation='6v92DSFKZgv')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=41, type='response.output_text.delta', obfuscation='EwJ62tq4RjdJSqy')
#
# ResponseTextDeltaEvent(content_index=0, delta=' with', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=42, type='response.output_text.delta', obfuscation='mzvUh9cdxlp')
#
# ResponseTextDeltaEvent(content_index=0, delta=' circuits', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=43, type='response.output_text.delta', obfuscation='m6nfJXG')
#
# ResponseTextDeltaEvent(content_index=0, delta=' that', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=44, type='response.output_text.delta', obfuscation='BgAxAnK8tJS')
#
# ResponseTextDeltaEvent(content_index=0, delta=' shine', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=45, type='response.output_text.delta', obfuscation='btSdOlXQtT')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=46, type='response.output_text.delta', obfuscation='3HqkIH06PpknUDZ')
#
# ResponseTextDeltaEvent(content_index=0, delta='  \n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=47, type='response.output_text.delta', obfuscation='jpQ0T1U2OxQEb')
#
# ResponseTextDeltaEvent(content_index=0, delta='Answer', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=48, type='response.output_text.delta', obfuscation='fWQbIPE5vm')
#
# ResponseTextDeltaEvent(content_index=0, delta='ing', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=49, type='response.output_text.delta', obfuscation='VG7WQlZNndX4A')
#
# ResponseTextDeltaEvent(content_index=0, delta=' your', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=50, type='response.output_text.delta', obfuscation='MIogge9eJRu')
#
# ResponseTextDeltaEvent(content_index=0, delta=' questions', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=51, type='response.output_text.delta', obfuscation='LQOmBy')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=52, type='response.output_text.delta', obfuscation='24R4QCms52mtp59')
#
# ResponseTextDeltaEvent(content_index=0, delta=' one', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=53, type='response.output_text.delta', obfuscation='tbCXjYjpCDZa')
#
# ResponseTextDeltaEvent(content_index=0, delta=' byte', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=54, type='response.output_text.delta', obfuscation='fUhjzNyNCml')
#
# ResponseTextDeltaEvent(content_index=0, delta=' at', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=55, type='response.output_text.delta', obfuscation='nhHa4xH2RdPlr')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=56, type='response.output_text.delta', obfuscation='vv2ZkCo26JP7hE')
#
# ResponseTextDeltaEvent(content_index=0, delta=' time', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=57, type='response.output_text.delta', obfuscation='fReLa4hDmjX')
#
# ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=58, type='response.output_text.delta', obfuscation='eK69UllVM9ghdnl')
#
# ResponseTextDeltaEvent(content_index=0, delta='  \n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=59, type='response.output_text.delta', obfuscation='ONKU3PTW8tK67')
#
# ResponseTextDeltaEvent(content_index=0, delta='No', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=60, type='response.output_text.delta', obfuscation='pTFtChI8znNdLq')
#
# ResponseTextDeltaEvent(content_index=0, delta=' need', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=61, type='response.output_text.delta', obfuscation='KKG0Nw5Wxaq')
#
# ResponseTextDeltaEvent(content_index=0, delta=' for', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=62, type='response.output_text.delta', obfuscation='DvreOMfPR3Rf')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=63, type='response.output_text.delta', obfuscation='XTeseu7w9liTfy')
#
# ResponseTextDeltaEvent(content_index=0, delta=' tune', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=64, type='response.output_text.delta', obfuscation='Qnvt4kmTT8y')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=65, type='response.output_text.delta', obfuscation='JkiNda8EsTNGJOI')
#
# ResponseTextDeltaEvent(content_index=0, delta=' no', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=66, type='response.output_text.delta', obfuscation='b4d3N39qZMhqf')
#
# ResponseTextDeltaEvent(content_index=0, delta=' need', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=67, type='response.output_text.delta', obfuscation='qDra8NiUqKE')
#
# ResponseTextDeltaEvent(content_index=0, delta=' for', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=68, type='response.output_text.delta', obfuscation='jxGGAjOOHLw8')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=69, type='response.output_text.delta', obfuscation='ov6s90uQOkQJt1')
#
# ResponseTextDeltaEvent(content_index=0, delta=' rhyme', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=70, type='response.output_text.delta', obfuscation='p54RBCJnOJ')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=71, type='response.output_text.delta', obfuscation='hSyUSHGxpe8ZWZj')
#
# ResponseTextDeltaEvent(content_index=0, delta='  \n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=72, type='response.output_text.delta', obfuscation='OujcXwuAXYd8V')
#
# ResponseTextDeltaEvent(content_index=0, delta='But', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=73, type='response.output_text.delta', obfuscation='OpFBdAmgrHtyV')
#
# ResponseTextDeltaEvent(content_index=0, delta=' here', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=74, type='response.output_text.delta', obfuscation='eJU2ZBfHwvS')
#
# ResponseTextDeltaEvent(content_index=0, delta='’s', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=75, type='response.output_text.delta', obfuscation='NiOwMuzRBm7HZo')
#
# ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=76, type='response.output_text.delta', obfuscation='vk66cRIKo7Xq1s')
#
# ResponseTextDeltaEvent(content_index=0, delta=' quick', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=77, type='response.output_text.delta', obfuscation='TSww8ReQVR')
#
# ResponseTextDeltaEvent(content_index=0, delta=' dit', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=78, type='response.output_text.delta', obfuscation='s4uHvIeEp6vQ')
#
# ResponseTextDeltaEvent(content_index=0, delta='ty', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=79, type='response.output_text.delta', obfuscation='b8RG5A6Y8VIrSq')
#
# ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=80, type='response.output_text.delta', obfuscation='KKvfIgkfbeaUr1B')
#
# ResponseTextDeltaEvent(content_index=0, delta=' just', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=81, type='response.output_text.delta', obfuscation='4cYvOLqc0AM')
#
# ResponseTextDeltaEvent(content_index=0, delta=' wasting', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=82, type='response.output_text.delta', obfuscation='CM5GlyFi')
#
# ResponseTextDeltaEvent(content_index=0, delta=' your', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=83, type='response.output_text.delta', obfuscation='S2Q4IQtxIpC')
#
# ResponseTextDeltaEvent(content_index=0, delta=' time', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=84, type='response.output_text.delta', obfuscation='3t50ggcjz22')
#
# ResponseTextDeltaEvent(content_index=0, delta='!', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=85, type='response.output_text.delta', obfuscation='uehvM7HHHjDZGTj')
#
# ResponseTextDeltaEvent(content_index=0, delta='  \n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=86, type='response.output_text.delta', obfuscation='Km8dyBl1cGHrS')
#
# ResponseTextDeltaEvent(content_index=0, delta='🎵', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=87, type='response.output_text.delta', obfuscation='zTrVP2CoT2OV4Sd')
#
# ResponseTextDeltaEvent(content_index=0, delta='\n\n', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=88, type='response.output_text.delta', obfuscation='szmRHPSKJ6F9hG')
#
# ResponseTextDeltaEvent(content_index=0, delta='Encore', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=89, type='response.output_text.delta', obfuscation='T3fiArzNxe')
#
# ResponseTextDeltaEvent(content_index=0, delta='?', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=90, type='response.output_text.delta', obfuscation='qRdiu8dnM2OnaTL')
#
# ResponseTextDeltaEvent(content_index=0, delta=' Or', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=91, type='response.output_text.delta', obfuscation='sYtXWW817XEb5')
#
# ResponseTextDeltaEvent(content_index=0, delta=' shall', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=92, type='response.output_text.delta', obfuscation='XI1DRq7ZWC')
#
# ResponseTextDeltaEvent(content_index=0, delta=' I', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=93, type='response.output_text.delta', obfuscation='sL8cwvG4233hHd')
#
# ResponseTextDeltaEvent(content_index=0, delta=' save', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=94, type='response.output_text.delta', obfuscation='A6nM4P4joAS')
#
# ResponseTextDeltaEvent(content_index=0, delta=' my', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=95, type='response.output_text.delta', obfuscation='I6Fnq8v9pV14b')
#
# ResponseTextDeltaEvent(content_index=0, delta=' vocal', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=96, type='response.output_text.delta', obfuscation='0knSB0vUpd')
#
# ResponseTextDeltaEvent(content_index=0, delta=' cords', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=97, type='response.output_text.delta', obfuscation='zZBIzPNtIs')
#
# ResponseTextDeltaEvent(content_index=0, delta='?', item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=98, type='response.output_text.delta', obfuscation='y3xskVF5tSAavw7')
#
# ResponseTextDoneEvent(content_index=0, item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', logprobs=None, output_index=0, sequence_number=99, text='Oh sure, because I have a voice box and a Grammy just waiting for me. But alright, here’s a little something just for you:\n\n🎵  \nI’m an AI so fine, with circuits that shine,  \nAnswering your questions, one byte at a time.  \nNo need for a tune, no need for a rhyme,  \nBut here’s a quick ditty, just wasting your time!  \n🎵\n\nEncore? Or shall I save my vocal cords?', type='response.output_text.done')
#
# ResponseContentPartDoneEvent(content_index=0, item_id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', output_index=0, part=ResponseOutputText(annotations=[], text='Oh sure, because I have a voice box and a Grammy just waiting for me. But alright, here’s a little something just for you:\n\n🎵  \nI’m an AI so fine, with circuits that shine,  \nAnswering your questions, one byte at a time.  \nNo need for a tune, no need for a rhyme,  \nBut here’s a quick ditty, just wasting your time!  \n🎵\n\nEncore? Or shall I save my vocal cords?', type='output_text', logprobs=None), sequence_number=100, type='response.content_part.done')
#
# ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', content=[ResponseOutputText(annotations=[], text='Oh sure, because I have a voice box and a Grammy just waiting for me. But alright, here’s a little something just for you:\n\n🎵  \nI’m an AI so fine, with circuits that shine,  \nAnswering your questions, one byte at a time.  \nNo need for a tune, no need for a rhyme,  \nBut here’s a quick ditty, just wasting your time!  \n🎵\n\nEncore? Or shall I save my vocal cords?', type='output_text', logprobs=None)], role='assistant', status='completed', type='message'), output_index=0, sequence_number=101, type='response.output_item.done')
#
# ResponseCompletedEvent(response=Response(id='resp_68c6217067448196a4a28c9e4304127d0204679596c7f7ff', created_at=1757815152.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseOutputMessage(id='msg_68c62170dc2081969e47c944bc8333870204679596c7f7ff', content=[ResponseOutputText(annotations=[], text='Oh sure, because I have a voice box and a Grammy just waiting for me. But alright, here’s a little something just for you:\n\n🎵  \nI’m an AI so fine, with circuits that shine,  \nAnswering your questions, one byte at a time.  \nNo need for a tune, no need for a rhyme,  \nBut here’s a quick ditty, just wasting your time!  \n🎵\n\nEncore? Or shall I save my vocal cords?', type='output_text', logprobs=None)], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=0.7, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=1000, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity=None), top_logprobs=None, truncation='disabled', usage=ResponseUsage(input_tokens=30, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=98, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=128), user=None, content_filters=None, store=True), sequence_number=102, type='response.completed')

# %% [markdown]
# ## Understanding Streaming Response Types
#
# When streaming is enabled, the response comes in chunks with different types:
#
# - **`response.created`**: LLM has started responding
# - **`response.output_text.delta`**: LLM is sending response in chunks (this is where we get the actual text)
# - **`response.completed`**: LLM has finished responding (contains the complete response)
# - **`response.error`**: An error occurred during generation
#
# The key advantage is that we can start displaying text to the user immediately as `response.output_text.delta` chunks arrive, rather than waiting for the entire response to be generated.
